# %%
import pandas as pd
import seaborn as sns

# %%
df_final=pd.read_csv("final_df")

sns.boxplot(x='Air Flow Rate from Mass Flow Sensor [g/s]',y='label',data=df_final)
# Out:
# C:\Users\KDIVA\miniconda3\envs\my-conda-env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KDIVA\miniconda3\envs\my-conda-env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\KDIVA\miniconda3\envs\my-conda-env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Air Flow Rate from Mass Flow Sensor [g/s]', ylabel='label'>

# %%
df_final
# Out:
#          Unnamed: 0.1  Unnamed: 0          Time  \
# 0                   0           0  14:15:47.209
# 1                   1           1  14:15:47.299
# 2                   2           2  14:15:47.389
# 3                   3           3  14:15:47.480
# 4                   4           4  14:15:47.569
# ...               ...         ...           ...
# 2693819         22516       22516  17:26:52.590
# 2693820         22517       22517  17:26:52.680
# 2693821         22518       22518  17:26:52.771
# 2693822         22519       22519  17:26:52.861
# 2693823         22520       22520  17:26:52.950
#
#          Engine Coolant Temperature [°C]  \
# 0                                   43.0
# 1                                   43.0
# 2                                   43.0
# 3                                   43.0
# 4                                   43.0
# ...                                  ...
# 2693819                             87.0
# 2693820                             87.0
# ...
